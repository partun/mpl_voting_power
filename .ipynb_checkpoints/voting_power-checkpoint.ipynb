# %%
import csv
import os
import classes as vp
import plot
import mathHelper as mh

# %%
def loadSessions(file = 'sessions.csv', csv_data_dir = './csv_data'):
    #load session data form sessions.csv
    sessions = [] #list of all the sessions
    with open(file) as sessions_csv:
        sessionno = 0
        csv_reader = csv.reader(sessions_csv, delimiter=',')
        for l in csv_reader:
            sessions.append(vp.Session(sessionno, l[1], l[2], csv_data_dir + '/' + l[3]))
            sessionno += 1
    return sessions

# %%
#todo: need output
def loadFactions(file = 'factions.csv'):
    with open(file) as factions_csv:
    lineno = 0
    csv_reader = csv.reader(factions_csv, delimiter=',')
    for line in csv_reader:
        if lineno != 0:
            factions.append(line[1])
            memno.append(line[2])
        lineno += 1
# Out:
#   File "<ipython-input-3-4df89e1468f9>", line 4
#     lineno = 0
#          ^
# IndentationError: expected an indented block

# %%
def parseMems(r, session):
    posIdMap = []
    line = next(r)
    start = 0
    end = 0
    for i, item in enumerate(line):
        if item == 'CouncillorId':
            start = i+1
            break
    
    next(r)
    
    #enumerate ID
    for i, item in enumerate(line[start:]):
        if item == '':
            end = i + start
            break
            
        posIdMap.append(item)
        if not item in members:
            members[item] = vp.Member(item)
        (members[item].ismem).append(session.idno)

    ''' 
    #enumerate bioid
    line = next(r)    
    for i,item in enumerate(line[start:end]):
        members[posIdMap[i]].bioid = item
    '''
    
    #enumerate name
    line = next(r)
    for i,item in enumerate(line[start:end]):
        #print(i), print(item)
        members[posIdMap[i]].name = item
        
    #skip line (this line only shows members are part of national council)
    next(r)
    #enumerate faction membership
    line = next(r)
    for i,item in enumerate(line[start:end]):
        members[posIdMap[i]].faction = item 
        
    #enumerate canton
    line = next(r)
    for i,item in enumerate(line[start:end]):
        members[posIdMap[i]].canton = item
        
    #enumerate birthdata
    line = next(r)
    for i,item in enumerate(line[start:end]):
        members[posIdMap[i]].birthdate = item

# %%
#parses all the sessions for the votes
def parseVotes(r, s):
    l = next(r)
    voters = []
    #votes = []
    voteno = 0
    start = 0
    while l[0] != 'VoteDate':
        l = next(r)
        start += 1
    
    #voters contains all the voters in a session
    endVotes = 0
    for i, item in enumerate(l[12:]):
        if item != 'Decision':
            voters.append(item)
        else:
            endVotes = i + 12
            break
    #print(len(voters))
    
    g = set()
    l = next(r)
    
    
    #need to handle:
    vote_none = '' #member was not yet or is no longer a national coucil member
    vote_yes = 'Ja'
    vote_no = 'Nein'
    vote_novote = ['Entschuldigt', 'Hat nicht teilgenommen']
    vote_abstain = 'Enthaltung'
    vote_pres = 'Der Präsident stimmt nicht'
    decision_yes = 'Yes'
    decision_no = 'No'
    
    
    while True:
        try:
            #store vote meta data
            v = vp.Vote(voteno)
            v.date = l[0]
            v.affairId = l[4]
            v.title = l[5]
            v.session = s
            #store how each member voted by adding the members bioid to the yes/no/abstain/noset set
            for i, item in enumerate(l[12:endVotes]):
                if item == vote_none:
                    pass
                elif item == vote_yes:
                    v.yes.add(voters[i])
                elif item == vote_no:
                    v.no.add(voters[i])
                elif item == vote_abstain:
                    v.abstain.add(voters[i])
                elif item in vote_novote:
                    v.novote.add(voters[i])
            
            #store decision data as stored in file and compare with calculated decision value
            if l[endVotes] == v.getDecision():
                if l[endVotes] == decision_yes:
                    v.decision = 'yes'
                elif l[endVotes] == decision_no:
                    v.decision = 'no'
            else:
                #unknown decision value
                v.dision = 'err: \"' + l[endVotes] + '/"' 
            
            votes.append(v)
            voteno += 1
            l = next(r)
        except StopIteration:
            break

# %%
def parseFiles(sessions, toParse = {}): 
    #parse all the files
    #for testing: "filesToParse" can limit the parsed files (everything if empty)
    for s in sessions:
        if s.idno in toParse or len(toParse) == 0:
            with open(s.path) as csv_file:
                csv_reader = csv.reader(csv_file, delimiter=',')
                print('-', end='')
                #print(str(key) + '. reading ... ' + csv_file.name)
                #parseFile(csv_reader)
                #parseMems(csv_reader, s)
                parseVotes(csv_reader, s)
                csv_file.close

# %%
members = dict()
votes = []
factions = dict()
#factions = []
memno = []

# %%
sessions = loadSessions()
parseFiles(sessions, toParse={0})
# Out:
# -
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-d54425bbe6aa> in <module>
#       1 sessions = loadSessions()
# ----> 2 parseFiles(sessions, toParse={0})
#       3
#       4
#
# <ipython-input-6-d63c28d9eb41> in parseFiles(sessions, toParse)
#      10                 #parseFile(csv_reader)
#      11                 #parseMems(csv_reader, s)
# ---> 12                 parseVotes(csv_reader, s)
#      13                 csv_file.close
#
# <ipython-input-17-24079c47e56b> in parseVotes(r, s)
#      57
#      58             #other data
# ---> 59             if l[endVotes] == v.getDecision():
#      60                 if l[endVotes] == decision_yes:
#      61                     v.decision = 'yes'
#
# AttributeError: 'Vote' object has no attribute 'getDecision'

# %%
for v in votes:
    print(v)
# Out:
# 0 yes Yes yes:114 no:42 abstain:0 novote:43
# 1 yes Yes yes:88 no:77 abstain:1 novote:33
# 2 yes Yes yes:157 no:0 abstain:0 novote:42
# 3 no No yes:76 no:90 abstain:0 novote:33
# 4 yes Yes yes:124 no:51 abstain:5 novote:19
# 5 yes Yes yes:125 no:51 abstain:5 novote:18
# 6 yes Yes yes:125 no:58 abstain:2 novote:14
# 7 yes Yes yes:103 no:77 abstain:3 novote:16
# 8 yes Yes yes:116 no:52 abstain:4 novote:27
# 9 yes Yes yes:124 no:48 abstain:3 novote:24
# 10 no No yes:74 no:100 abstain:2 novote:23
# 11 yes Yes yes:129 no:48 abstain:0 novote:22
# 12 yes Yes yes:95 no:90 abstain:1 novote:13
# 13 yes Yes yes:94 no:86 abstain:3 novote:16
# 14 yes Yes yes:131 no:43 abstain:9 novote:16
# 15 yes Yes yes:99 no:59 abstain:0 novote:41
# 16 no No yes:83 no:88 abstain:1 novote:27
# 17 yes Yes yes:105 no:73 abstain:0 novote:21
# 18 yes Yes yes:93 no:92 abstain:1 novote:14
# 19 yes Yes yes:115 no:72 abstain:0 novote:12
# 20 no No yes:29 no:155 abstain:2 novote:13
# 21 yes Yes yes:138 no:43 abstain:0 novote:18
# 22 yes Yes yes:103 no:71 abstain:0 novote:25
# 23 yes Yes yes:117 no:57 abstain:0 novote:25
# 24 yes Yes yes:116 no:53 abstain:0 novote:30
# 25 no No yes:60 no:127 abstain:0 novote:12
# 26 no No yes:0 no:139 abstain:48 novote:12
# 27 yes Yes yes:95 no:57 abstain:27 novote:20
# 28 yes Yes yes:98 no:85 abstain:0 novote:16
# 29 yes Yes yes:97 no:78 abstain:1 novote:23
# 201 yes Yes yes:122 no:56 abstain:0 novote:21
# 202 yes Yes yes:115 no:69 abstain:1 novote:14
# 203 no No yes:91 no:94 abstain:1 novote:13
# 204 no No yes:83 no:105 abstain:0 novote:11
# 205 no No yes:88 no:98 abstain:2 novote:11
# 206 no No yes:78 no:110 abstain:0 novote:11
# 207 yes Yes yes:101 no:81 abstain:6 novote:11
# 208 no No yes:83 no:102 abstain:3 novote:11
# 209 yes Yes yes:132 no:51 abstain:6 novote:10
# 210 yes Yes yes:169 no:11 abstain:1 novote:18
# 211 yes Yes yes:115 no:68 abstain:6 novote:10
# 212 yes Yes yes:95 no:93 abstain:1 novote:10
# 213 no No yes:88 no:96 abstain:3 novote:12
# 214 no No yes:81 no:106 abstain:2 novote:10
# 215 no No yes:85 no:103 abstain:2 novote:9
# 216 no No yes:71 no:116 abstain:4 novote:8
# 217 yes Yes yes:145 no:36 abstain:9 novote:9
# 218 yes Yes yes:192 no:0 abstain:2 novote:5
# 219 yes Yes yes:129 no:62 abstain:3 novote:5
# 220 yes Yes yes:121 no:53 abstain:20 novote:5
# 221 yes Yes yes:130 no:61 abstain:3 novote:5
# 222 yes Yes yes:182 no:10 abstain:4 novote:3
# 223 yes Yes yes:139 no:56 abstain:1 novote:3
# 224 yes Yes yes:156 no:32 abstain:7 novote:4
# 225 yes Yes yes:193 no:0 abstain:2 novote:4
# 226 yes Yes yes:139 no:52 abstain:5 novote:3
# 227 yes Yes yes:139 no:50 abstain:5 novote:5
# 228 yes Yes yes:141 no:50 abstain:5 novote:3
# 229 yes Yes yes:139 no:51 abstain:5 novote:4
# 230 yes Yes yes:142 no:50 abstain:5 novote:2
# 231 yes Yes yes:142 no:49 abstain:5 novote:3
# 232 yes Yes yes:144 no:49 abstain:2 novote:4
# 233 yes Yes yes:141 no:51 abstain:4 novote:3
# 234 yes Yes yes:144 no:49 abstain:4 novote:2
# 235 yes Yes yes:144 no:50 abstain:3 novote:2
# 236 yes Yes yes:192 no:0 abstain:1 novote:6
# 237 yes Yes yes:140 no:52 abstain:3 novote:4
# 238 yes Yes yes:147 no:45 abstain:3 novote:4
# 239 yes Yes yes:159 no:1 abstain:35 novote:4

# %%
#counts the members of each faction per session
factions = dict()
for mem in members:
    f = members[mem].faction
    for s in members[mem].ismem:
        if s in factions:
            if f in factions[s]:
                factions[s][f] += 1
            else:
                factions[s][f] = 1
        else:
            factions[s] = dict()
            factions[s][f] = 1

# %%
for s in factions:
    memsum = 0
    for f in factions[s]:
        if f != 'sum':
            memsum += factions[s][f]
    factions[s]['sum'] = memsum

# %%
def eqDictSet(d):
    out = set()

# %%
factions

# %%
def extendSet(s, x):
    for i in x:
        if i != '' and i != 'CouncillorName':
            s.add(i)

# %%
def extendDict(d, l):
    for i in l:
        if i == '' or i == 'Fraktion':
            continue
        if i in d:
            d[i] +=1
        else:
            d[i] = 1

# %%
def parseFile(file):
    lineno = 0
    for line in file:
        votes.add(line[20])
        if lineno == 2:
            extendSet(members, line)
        if lineno == 4:
            extendDict(faction, line)
        if lineno == 8:
            print(line)
        lineno += 1

# %%
len(set())

# %%
print(members['3008'].ismem)

# %%
mh.dictPrint(members)
